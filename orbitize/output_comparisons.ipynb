# %%
import test_kepler as kepler #computations that convert the mean anomaly to the eccentric anomaly
#the function is called kepler, so to call it use kepler.kepler(mean anomally array, 
#eccentricity array of just one value of same length as mean anomaly)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a070e342fda7> in <module>
# ----> 1 import test_kepler as kepler #computations that convert the mean anomaly to the eccentric anomaly
#       2 #the function is called kepler, so to call it use kepler.kepler(mean anomally array,
#       3 #eccentricity array of just one value of same length as mean anomaly)
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'test_kepler'
